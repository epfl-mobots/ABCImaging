# %%
import os
import numpy as np
import cv2

import matplotlib.pyplot as plt
from keras.models import load_model
from tqdm  import tqdm
import glob
from datetime import datetime

import tensorflow as tf

# Add the upper level directory to the path
import sys
sys.path.append('..')
import imutils as im

# %% [markdown]
# # Overall approach for Cell Content Identification
#
# The following approach is taken from DeepBee https://github.com/AvsThiago/DeepBee-source. The preprocessing was additionally created to remove/reduce the number of bees on the beehive frame and provide visibility of the uncovered cells.
#
# -foreground substraction
#     some method to remove the bees covering the openings of the cells
#
# -image segmentation
#
# -classification
#     capped honey cells
#     capped brood cells
#     pollen cells
#     open honey cells
#     open brood cells (empty)
#     open brood cells(eggs)
#     open brood cells(larvae)
#     other
#
# Since the code of the DeepBee project is not freely accessible, the compiled .exe program was tested to classify the cell content.
#
#
# The images taken for testing the code can be found in the folder 24.04_observation_OH. Computationally removing the bees using the provided photos was done using different number of images. Since the bee cluster/colony is mostly located at the same area of the frame, a dark shade at that region can be seen. The cells themselves are still not very well visible for the tested algorithms.
#
# To remove the bees, the two functions createBackgroundSubtractorMOG2 and createBackgroundSubtractorKNN were used with different parameters. The chosen functions seem to be computing the desired output but based on the input images provided, a complete removal of the honey bees on the frame seems to be rather complicated. For all parameters and sufficiently large number of images (some 100), bees themselves vanish but a dark region covering the cells appears. -> hard to extract data in region of bee cluster
#
# backSub = cv2.createBackgroundSubtractorMOG2(history=len(images), varThreshold=16, detectShadows=False)
# backSub = cv2.createBackgroundSubtractorKNN(detectShadows=True)

# %%
def get_all_file_paths(directory):
    file_paths = []
    for root, directories, files in os.walk(directory):
        for filename in files:
            file_path = os.path.join(root, filename)
            file_paths.append(file_path)
    return file_paths

def load_images_from_folder(image_paths):
    images = []
    for filename in image_paths:  # Adjust the extension if needed
        img = cv2.imread(filename)
        if img is not None:
            images.append(img)
    return images

def remove_moving_objects(images):

    # Create background subtractor
#     backSub = cv2.createBackgroundSubtractorMOG2(history=len(images), varThreshold=16, detectShadows=False)
    backSub = cv2.createBackgroundSubtractorKNN(detectShadows=True) # 2 different methods to subtract the backgrounds

    # Apply the background subtractor to each image to build the background model
    for img in images:
        backSub.apply(img)

    # Now, obtain the background model
    background_image = backSub.getBackgroundImage()

    return background_image

# %% [markdown]
# # Preprocessing

# %%
# Example usage
root = '/Users/cyrilmonette/Desktop/EPFL 2018-2026/PhD - Mobots/data/24.09_observation_OH/Images/'

directory = root + r"\24.04_observation_OH\24.04_observation_OH\Images\h2r2_1minute\all_images".format(drive_letter)

for num_days in [0.5,1, 2, 3]:
    first_index = int(num_days*60*24) # last n hours
    downsampling = 20 #60

    image_paths_all = get_all_file_paths(directory)
    image_paths_most_recent = image_paths_all[-first_index:]
    image_paths = image_paths_most_recent[::downsampling]

    images = load_images_from_folder(image_paths)

    now = datetime.now()

    # Format it in a human-readable way
    timestamp = now.strftime("%Y-%m-%d_%H-%M-%S")

    # Create a directory to save the processed images
    output_folder = root +"\output\{}_imgs{}_numdays{}_step{}".format(timestamp, len(images), num_days, downsampling)
    os.makedirs(output_folder, exist_ok=True)

    # Example usage

    if len(images) > 0:
        print("Number of images:", len(images))
        result_image = remove_moving_objects(images)

        background_filename = output_folder + '\\background_image{}_imgs{}_numdays{}_step{}.jpg'.format(first_index, len(images), num_days, downsampling)
        print(background_filename)
        cv2.imwrite(background_filename, result_image)
    #     cv2.imshow('Result', result_image)
    #     cv2.waitKey(0)
    #     cv2.destroyAllWindows()
    else:
        print("No images found in the specified folder.")
    del images, result_image
# reads the last background image
result_image = cv2.imread(background_filename)
# Out:
# Number of images: 36
# E:\MobotsGroup\output\2024-09-11_10-23-03_imgs36_numdays0.5_step20\background_image720_imgs36_numdays0.5_step20.jpg
# Number of images: 72
# E:\MobotsGroup\output\2024-09-11_10-23-59_imgs72_numdays1_step20\background_image1440_imgs72_numdays1_step20.jpg
# Number of images: 144
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 30
#      28 if len(images) > 0:
#      29     print("Number of images:", len(images))
# ---> 30     result_image = remove_moving_objects(images)
#      32     background_filename = output_folder + '\\background_image{}_imgs{}_numdays{}_step{}.jpg'.format(first_index, len(images), num_days, downsampling)
#      33     print(background_filename)
#
# Cell In[5], line 25, in remove_moving_objects(images)
#      21 #    backSub = cv2.createBackgroundSubtractorKNN(detectShadows=True) # 2 different methods to subtract the backgrounds
#      22
#      23     # Apply the background subtractor to each image to build the background model
#      24     for img in images:
# ---> 25         backSub.apply(img)
#      27     # Now, obtain the background model
#      28     background_image = backSub.getBackgroundImage()
#
# KeyboardInterrupt:

# %%
background_filename = r"E:\MobotsGroup\output\2024-08-09_15-33-50_imgs216_numdays3_step20\background_image4320_imgs216_numdays3_step20.jpg"
result_image = cv2.imread(background_filename)
print(background_filename)
# Out:
# E:\MobotsGroup\output\2024-08-09_15-33-50_imgs216_numdays3_step20\background_image4320_imgs216_numdays3_step20.jpg

# %%
# additional work done to create filter indicating the location of bees:

# %%
def compare_images(img1, img2, scale=1.0):
    """
    Compare two images and create a new image highlighting the changes.
    
    Parameters:
    - img1: First image (cv2 image object)
    - img2: Second image (cv2 image object)
    - scale: Scaling factor for the differences
    
    Returns:
    - diff_img: Image representing the pixel-wise differences
    """
    if img1.shape != img2.shape:
        raise ValueError("Input images must have the same dimensions")

    img1 = img1.astype(np.float32)
    img2 = img2.astype(np.float32)

    diff_img = np.abs(img1 - img2)

    # Scale the difference image to make the changes more visible
    diff_img *= scale

    # Clip values to the valid range [0, 255] and convert to uint8
    diff_img = np.clip(diff_img, 0, 255).astype(np.uint8)

    return diff_img

def brighten_image_with_mask(main_img, mask_img, max_increase=1.0):
    """
    Brighten the main image using the mask image, proportional to the mask's pixel values.
    
    Parameters:
    - main_img: Main image (cv2 image object, should be uint8)
    - mask_img: Mask image (cv2 image object, should be uint8, same size as main_img)
    - max_increase: Maximum scaling factor to increase brightness based on mask

    Returns:
    - brightened_img: Image with brightness increased based on mask
    """
    if main_img.shape != mask_img.shape:
        raise ValueError("Main image and mask image must have the same dimensions")

    main_img = main_img.astype(np.float32)

    # Normalize mask to range [0, 1] by dividing by 255 (if the mask is uint8)
    mask_img = mask_img.astype(np.float32) / 255.0

    # Increase brightness proportional to the mask values
    brightened_img = main_img + (mask_img * max_increase * 255)

    brightened_img = np.clip(brightened_img, 0, 255).astype(np.uint8)
    
    print("Min pixel value:", mask_img.min())
    print("Max pixel value:", mask_img.max())
    mask_img = (mask_img.astype(np.float32) * 255.0).astype(np.uint8)

    return brightened_img, mask_img

def scale_image(image, scale_factor = 0.5):
    height, width = image.shape[:2]

    new_width = int(width * scale_factor)
    new_height = int(height * scale_factor)

    # Resize the image while keeping aspect ratio
    resized_image = cv2.resize(image, (new_width, new_height), interpolation=cv2.INTER_AREA)
    return resized_image


# recursive call of the functions to remove the bees:
def recursive_bee_remover(first_image, second_image, max_increase = 1.0):
    diff_img = compare_images(first_image, second_image, scale=1.0)
    brightened_img, img_mask = brighten_image_with_mask(first_image, diff_img, max_increase)
    return brightened_img, img_mask

def mask_average(mask_list):
    average = np.zeros_like(mask_list[0], dtype=np.float32)  # Use float32 for precision
    for mask in mask_list:
        mask = mask.astype(np.float32)  # Convert each mask to float32 to avoid overflow issues
        average += mask 
    average = average / len(mask_list)
    
    average = np.clip(average, 0, 255).astype(np.uint8)
    
    return average
    


def store_image(image, root, folder_name, name_extension):
    folder_path = root + "\\" + folder_name
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
        print(f'Folder created at: {folder_path}')
    else:
        print(f'Folder already exists at: {folder_path}', "now saving", name_extension)    
    file_path =  str(root + folder_name + '\\' + folder_name + name_extension+".png")
    print(file_path)
    cv2.imwrite(file_path, image)

# %%
# get files in base directory
"""
base_dir: directory containing the set of images of the hive to remove the bees
root : root directory where the computed masks and resulting images will be stored at
"""

# base directory for images (input)
base_dir = r"C:\Users\raf-k\Desktop\MOBOTS Group project\cell classification\code\images"
base_dir = r"G:\MobotsGroup\24.04_observation_OH\24.04_observation_OH\Images\h2r3_1minute\all_images"
# directory for output 
root = r"G:\MobotsGroup\cell_classification_KNN"
background_filenames = [os.path.join(base_dir, f) for f in os.listdir(base_dir) if os.path.isfile(os.path.join(base_dir, f))]

# %%
root
# Out:
# 'E:\\MobotsGroup\\cell_classification_KNN'

# %%
first_image = cv2.imread(background_filenames[0])
# background_filenames = background_filenames[::3]
image_list = []
mask_list = []
num_images = 40
algorithm_name = "\\recursive_{}_imgs".format(str(num_images))
for filename in background_filenames[1:num_images]:
    second_image = cv2.imread(filename)
    result_img, img_mask = recursive_bee_remover(first_image, second_image, 1)
    print(background_filenames.index(filename)/len(background_filenames)*100, "%")
    print(root + algorithm_name)

    store_image(img_mask, root + algorithm_name, "\\recursive_masks_{}".format(num_images), "_mask_recursive_{}".format(background_filenames.index(filename)))
    store_image(result_img, root + algorithm_name, "\\recursive_subimages_{}".format(num_images), "_subimages_recursive_{}".format(background_filenames.index(filename)))

    image_list.append(result_img)
    mask_list.append(img_mask)
    first_image = second_image
        
result = remove_moving_objects(image_list)
store_image(result, root + algorithm_name,'', "result_recursive_{}".format(num_images))
resized_image = scale_image(result, 0.5)
# cv2.imshow('Brightened Img recursive n to n+1', resized_image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# Out:
# Min pixel value: 0.0
# Max pixel value: 0.8627451
# 1.1494252873563218 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_1
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_1.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_1
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_1.png
# Min pixel value: 0.0
# Max pixel value: 0.8627451
# 2.2988505747126435 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_2
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_2.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_2
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_2.png
# Min pixel value: 0.0
# Max pixel value: 0.8666667
# 3.4482758620689653 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_3
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_3.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_3
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_3.png
# Min pixel value: 0.0
# Max pixel value: 0.8627451
# 4.597701149425287 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_4
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_4.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_4
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_4.png
# Min pixel value: 0.0
# Max pixel value: 0.8784314
# 5.747126436781609 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_5
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_5.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_5
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_5.png
# Min pixel value: 0.0
# Max pixel value: 0.8039216
# 6.896551724137931 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_6
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_6.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_6
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_6.png
# Min pixel value: 0.0
# Max pixel value: 0.92156863
# 8.045977011494253 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_7
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_7.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_7
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_7.png
# Min pixel value: 0.0
# Max pixel value: 0.85490197
# 9.195402298850574 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_8
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_8.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_8
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_8.png
# Min pixel value: 0.0
# Max pixel value: 0.8745098
# 10.344827586206897 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_9
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_9.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_9
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_9.png
# Min pixel value: 0.0
# Max pixel value: 0.79607844
# 11.494252873563218 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_10
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_10.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_10
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_10.png
# Min pixel value: 0.0
# Max pixel value: 0.8509804
# 12.643678160919542 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_11
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_11.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_11
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_11.png
# Min pixel value: 0.0
# Max pixel value: 0.89411765
# 13.793103448275861 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_12
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_12.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_12
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_12.png
# Min pixel value: 0.0
# Max pixel value: 0.9882353
# 14.942528735632186 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_13
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_13.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_13
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_13.png
# Min pixel value: 0.0
# Max pixel value: 0.84705883
# 16.091954022988507 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_14
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_14.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_14
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_14.png
# Min pixel value: 0.0
# Max pixel value: 0.8980392
# 17.24137931034483 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_15
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_15.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_15
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_15.png
# Min pixel value: 0.0
# Max pixel value: 0.87058824
# 18.39080459770115 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_16
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_16.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_16
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_16.png
# Min pixel value: 0.0
# Max pixel value: 0.827451
# 19.54022988505747 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_17
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_17.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_17
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_17.png
# Min pixel value: 0.0
# Max pixel value: 0.84705883
# 20.689655172413794 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_18
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_18.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_18
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_18.png
# Min pixel value: 0.0
# Max pixel value: 0.8352941
# 21.839080459770116 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_19
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_19.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_19
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_19.png
# Min pixel value: 0.0
# Max pixel value: 0.9411765
# 22.988505747126435 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_20
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_20.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_20
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_20.png
# Min pixel value: 0.0
# Max pixel value: 0.96862745
# 24.137931034482758 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_21
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_21.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_21
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_21.png
# Min pixel value: 0.0
# Max pixel value: 0.8352941
# 25.287356321839084 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_22
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_22.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_22
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_22.png
# Min pixel value: 0.0
# Max pixel value: 0.92941177
# 26.436781609195403 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_23
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_23.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_23
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_23.png
# Min pixel value: 0.0
# Max pixel value: 0.84705883
# 27.586206896551722 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_24
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_24.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_24
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_24.png
# Min pixel value: 0.0
# Max pixel value: 0.83137256
# 28.735632183908045 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_25
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_25.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_25
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_25.png
# Min pixel value: 0.0
# Max pixel value: 0.79607844
# 29.88505747126437 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_26
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_26.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_26
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_26.png
# Min pixel value: 0.0
# Max pixel value: 0.85882354
# 31.03448275862069 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_27
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_27.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_27
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_27.png
# Min pixel value: 0.0
# Max pixel value: 0.7921569
# 32.18390804597701 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_28
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_28.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_28
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_28.png
# Min pixel value: 0.0
# Max pixel value: 0.83137256
# 33.33333333333333 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_29
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_29.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_29
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_29.png
# Min pixel value: 0.0
# Max pixel value: 0.8392157
# 34.48275862068966 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_30
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_30.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_30
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_30.png
# Min pixel value: 0.0
# Max pixel value: 0.9098039
# 35.63218390804598 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_31
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_31.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_31
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_31.png
# Min pixel value: 0.0
# Max pixel value: 0.8
# 36.7816091954023 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_32
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_32.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_32
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_32.png
# Min pixel value: 0.0
# Max pixel value: 0.8392157
# 37.93103448275862 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_33
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_33.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_33
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_33.png
# Min pixel value: 0.0
# Max pixel value: 0.827451
# 39.08045977011494 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_34
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_34.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_34
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_34.png
# Min pixel value: 0.0
# Max pixel value: 0.77254903
# 40.229885057471265 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_35
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_35.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_35
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_35.png
# Min pixel value: 0.0
# Max pixel value: 0.827451
# 41.37931034482759 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_36
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_36.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_36
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_36.png
# Min pixel value: 0.0
# Max pixel value: 0.7372549
# 42.5287356321839 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_37
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_37.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_37
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_37.png
# Min pixel value: 0.0
# Max pixel value: 0.8156863
# 43.67816091954023 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_38
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_38.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_38
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_38.png
# Min pixel value: 0.0
# Max pixel value: 0.7019608
# 44.827586206896555 %
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_masks_40 now saving _mask_recursive_39
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_masks_40\\recursive_masks_40_mask_recursive_39.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\\recursive_subimages_40 now saving _subimages_recursive_39
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\recursive_subimages_40\\recursive_subimages_40_subimages_recursive_39.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\ now saving result_recursive_40
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\result_recursive_40.png

# %%
####  using the average of the consecutive masks
first_image = cv2.imread(background_filenames[0])
store_image(first_image, root + algorithm_name, '', "bees_averaged_original_{}".format(num_images))

image_list = []
mask_list = []

num_images = 40
skipped = 5 # to increase time between images
algorithm_name = "\\average_{}_imgs_skipped{}".format(num_images,skipped)
for filename in background_filenames[1:skipped * num_images][::skipped]:
    second_image = cv2.imread(filename)
    result_img, img_mask = recursive_bee_remover(first_image, second_image, 1.0)# here used to compute the mask
    print(filename)
    print(background_filenames.index(filename)/len(background_filenames) * 100, "%")
    image_list.append(result_img)
    mask_list.append(img_mask)
    store_image(img_mask, root + algorithm_name, "\\average_masks_{}".format(num_images), "_mask_averaged_{}".format(background_filenames.index(filename)))

    first_image = second_image
    
average_mask = mask_average(mask_list)
store_image(average_mask, root + algorithm_name,'', "mask_averaged_{}".format(num_images))

bees_removed_image = remove_moving_objects(image_list)
store_image(bees_removed_image, root + algorithm_name, '', "bees_removed_averaged_{}".format(num_images))


for max_increase in [.2, .4, .6, .8, 1, 1.,2, 1.4, 10]:
    # added gaussian blur over average mask 
    result, img_maskunused = brighten_image_with_mask(bees_removed_image, average_mask, max_increase)
    store_image(result, root + algorithm_name, '', "bees_removed_brightened_averaged_{}_".format(num_images)+str(max_increase))

    average_mask = cv2.GaussianBlur(average_mask, (7,7), 0)
    store_image(average_mask, root + algorithm_name, '', "average_mask_blurr{}_".format(num_images)+str(max_increase))

    result, img_maskunused = brighten_image_with_mask(bees_removed_image, average_mask, max_increase)
    store_image(result, root + algorithm_name, '', "bees_removed_brightened_averaged_blurr{}_".format(num_images)+str(max_increase))

    
# for filename in background_filenames:
#     image_list.append(cv2.imread(filename))
    
resized_image = scale_image(result, 0.5)
# cv2.imshow('Brightened Img with averaged mask', resized_image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# Out:
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\ now saving bees_averaged_original_40
# E:\MobotsGroup\cell_classification_KNN\recursive_40_imgs\bees_averaged_original_40.png
# Min pixel value: 0.0
# Max pixel value: 0.8627451
# E:\MobotsGroup\24.04_observation_OH\24.04_observation_OH\Images\h2r3_1minute\all_images\hive2_rpi3_240419-184802Z.jpg
# 1.1494252873563218 %
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\\average_masks_40 now saving _mask_averaged_1
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\average_masks_40\\average_masks_40_mask_averaged_1.png
# Min pixel value: 0.0
# Max pixel value: 0.9137255
# E:\MobotsGroup\24.04_observation_OH\24.04_observation_OH\Images\h2r3_1minute\all_images\hive2_rpi3_240420-072102Z.jpg
# 6.896551724137931 %
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\\average_masks_40 now saving _mask_averaged_6
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\average_masks_40\\average_masks_40_mask_averaged_6.png
# Min pixel value: 0.0
# Max pixel value: 0.94509804
# E:\MobotsGroup\24.04_observation_OH\24.04_observation_OH\Images\h2r3_1minute\all_images\hive2_rpi3_240420-144702Z.jpg
# 12.643678160919542 %
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\\average_masks_40 now saving _mask_averaged_11
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\average_masks_40\\average_masks_40_mask_averaged_11.png
# Min pixel value: 0.0
# Max pixel value: 0.98039216
# E:\MobotsGroup\24.04_observation_OH\24.04_observation_OH\Images\h2r3_1minute\all_images\hive2_rpi3_240421-033702Z.jpg
# 18.39080459770115 %
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\\average_masks_40 now saving _mask_averaged_16
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\average_masks_40\\average_masks_40_mask_averaged_16.png
# Min pixel value: 0.0
# Max pixel value: 0.8666667
# E:\MobotsGroup\24.04_observation_OH\24.04_observation_OH\Images\h2r3_1minute\all_images\hive2_rpi3_240421-181502Z.jpg
# 24.137931034482758 %
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\\average_masks_40 now saving _mask_averaged_21
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\average_masks_40\\average_masks_40_mask_averaged_21.png
# Min pixel value: 0.0
# Max pixel value: 0.9098039
# E:\MobotsGroup\24.04_observation_OH\24.04_observation_OH\Images\h2r3_1minute\all_images\hive2_rpi3_240422-075702Z.jpg
# 29.88505747126437 %
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\\average_masks_40 now saving _mask_averaged_26
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\average_masks_40\\average_masks_40_mask_averaged_26.png
# Min pixel value: 0.0
# Max pixel value: 0.8980392
# E:\MobotsGroup\24.04_observation_OH\24.04_observation_OH\Images\h2r3_1minute\all_images\hive2_rpi3_240423-024102Z.jpg
# 35.63218390804598 %
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\\average_masks_40 now saving _mask_averaged_31
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\average_masks_40\\average_masks_40_mask_averaged_31.png
# Min pixel value: 0.0
# Max pixel value: 0.83137256
# E:\MobotsGroup\24.04_observation_OH\24.04_observation_OH\Images\h2r3_1minute\all_images\hive2_rpi3_240424-023502Z.jpg
# 41.37931034482759 %
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\\average_masks_40 now saving _mask_averaged_36
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\average_masks_40\\average_masks_40_mask_averaged_36.png
# Min pixel value: 0.0
# Max pixel value: 0.7764706
# E:\MobotsGroup\24.04_observation_OH\24.04_observation_OH\Images\h2r3_1minute\all_images\hive2_rpi3_240424-051902Z.jpg
# 47.12643678160919 %
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\\average_masks_40 now saving _mask_averaged_41
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\average_masks_40\\average_masks_40_mask_averaged_41.png
# Min pixel value: 0.0
# Max pixel value: 0.8666667
# E:\MobotsGroup\24.04_observation_OH\24.04_observation_OH\Images\h2r3_1minute\all_images\hive2_rpi3_240425-062302Z.jpg
# 52.87356321839081 %
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\\average_masks_40 now saving _mask_averaged_46
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\average_masks_40\\average_masks_40_mask_averaged_46.png
# Min pixel value: 0.0
# Max pixel value: 0.99215686
# E:\MobotsGroup\24.04_observation_OH\24.04_observation_OH\Images\h2r3_1minute\all_images\hive2_rpi3_240425-131402Z.jpg
# 58.620689655172406 %
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\\average_masks_40 now saving _mask_averaged_51
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\average_masks_40\\average_masks_40_mask_averaged_51.png
# Min pixel value: 0.0
# Max pixel value: 0.91764706
# E:\MobotsGroup\24.04_observation_OH\24.04_observation_OH\Images\h2r3_1minute\all_images\hive2_rpi3_240426-024302Z.jpg
# 64.36781609195403 %
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\\average_masks_40 now saving _mask_averaged_56
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\average_masks_40\\average_masks_40_mask_averaged_56.png
# Min pixel value: 0.0
# Max pixel value: 0.7764706
# E:\MobotsGroup\24.04_observation_OH\24.04_observation_OH\Images\h2r3_1minute\all_images\hive2_rpi3_240426-105802Z.jpg
# 70.11494252873564 %
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\\average_masks_40 now saving _mask_averaged_61
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\average_masks_40\\average_masks_40_mask_averaged_61.png
# Min pixel value: 0.0
# Max pixel value: 0.85490197
# E:\MobotsGroup\24.04_observation_OH\24.04_observation_OH\Images\h2r3_1minute\all_images\hive2_rpi3_240427-062802Z.jpg
# 75.86206896551724 %
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\\average_masks_40 now saving _mask_averaged_66
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\average_masks_40\\average_masks_40_mask_averaged_66.png
# Min pixel value: 0.0
# Max pixel value: 0.91764706
# E:\MobotsGroup\24.04_observation_OH\24.04_observation_OH\Images\h2r3_1minute\all_images\hive2_rpi3_240427-235302Z.jpg
# 81.60919540229885 %
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\\average_masks_40 now saving _mask_averaged_71
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\average_masks_40\\average_masks_40_mask_averaged_71.png
# Min pixel value: 0.0
# Max pixel value: 0.73333335
# E:\MobotsGroup\24.04_observation_OH\24.04_observation_OH\Images\h2r3_1minute\all_images\hive2_rpi3_240428-092502Z.jpg
# 87.35632183908046 %
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\\average_masks_40 now saving _mask_averaged_76
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\average_masks_40\\average_masks_40_mask_averaged_76.png
# Min pixel value: 0.0
# Max pixel value: 0.7176471
# E:\MobotsGroup\24.04_observation_OH\24.04_observation_OH\Images\h2r3_1minute\all_images\hive2_rpi3_240428-155602Z.jpg
# 93.10344827586206 %
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\\average_masks_40 now saving _mask_averaged_81
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\average_masks_40\\average_masks_40_mask_averaged_81.png
# Min pixel value: 0.0
# Max pixel value: 0.7137255
# E:\MobotsGroup\24.04_observation_OH\24.04_observation_OH\Images\h2r3_1minute\all_images\hive2_rpi3_240429-104002Z.jpg
# 98.85057471264368 %
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\\average_masks_40 now saving _mask_averaged_86
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\average_masks_40\\average_masks_40_mask_averaged_86.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\ now saving mask_averaged_40
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\mask_averaged_40.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\ now saving bees_removed_averaged_40
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\bees_removed_averaged_40.png
# Min pixel value: 0.003921569
# Max pixel value: 0.3254902
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\ now saving bees_removed_brightened_averaged_40_0.2
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\bees_removed_brightened_averaged_40_0.2.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\ now saving average_mask_blurr40_0.2
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\average_mask_blurr40_0.2.png
# Min pixel value: 0.007843138
# Max pixel value: 0.2627451
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\ now saving bees_removed_brightened_averaged_blurr40_0.2
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\bees_removed_brightened_averaged_blurr40_0.2.png
# Min pixel value: 0.007843138
# Max pixel value: 0.2627451
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\ now saving bees_removed_brightened_averaged_40_0.4
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\bees_removed_brightened_averaged_40_0.4.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\ now saving average_mask_blurr40_0.4
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\average_mask_blurr40_0.4.png
# Min pixel value: 0.007843138
# Max pixel value: 0.25490198
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\ now saving bees_removed_brightened_averaged_blurr40_0.4
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\bees_removed_brightened_averaged_blurr40_0.4.png
# Min pixel value: 0.007843138
# Max pixel value: 0.25490198
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\ now saving bees_removed_brightened_averaged_40_0.6
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\bees_removed_brightened_averaged_40_0.6.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\ now saving average_mask_blurr40_0.6
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\average_mask_blurr40_0.6.png
# Min pixel value: 0.007843138
# Max pixel value: 0.2509804
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\ now saving bees_removed_brightened_averaged_blurr40_0.6
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\bees_removed_brightened_averaged_blurr40_0.6.png
# Min pixel value: 0.007843138
# Max pixel value: 0.2509804
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\ now saving bees_removed_brightened_averaged_40_0.8
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\bees_removed_brightened_averaged_40_0.8.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\ now saving average_mask_blurr40_0.8
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\average_mask_blurr40_0.8.png
# Min pixel value: 0.007843138
# Max pixel value: 0.2509804
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\ now saving bees_removed_brightened_averaged_blurr40_0.8
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\bees_removed_brightened_averaged_blurr40_0.8.png
# Min pixel value: 0.007843138
# Max pixel value: 0.2509804
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\ now saving bees_removed_brightened_averaged_40_1
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\bees_removed_brightened_averaged_40_1.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\ now saving average_mask_blurr40_1
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\average_mask_blurr40_1.png
# Min pixel value: 0.007843138
# Max pixel value: 0.2509804
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\ now saving bees_removed_brightened_averaged_blurr40_1
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\bees_removed_brightened_averaged_blurr40_1.png
# Min pixel value: 0.007843138
# Max pixel value: 0.2509804
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\ now saving bees_removed_brightened_averaged_40_1.0
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\bees_removed_brightened_averaged_40_1.0.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\ now saving average_mask_blurr40_1.0
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\average_mask_blurr40_1.0.png
# Min pixel value: 0.007843138
# Max pixel value: 0.24705882
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\ now saving bees_removed_brightened_averaged_blurr40_1.0
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\bees_removed_brightened_averaged_blurr40_1.0.png
# Min pixel value: 0.007843138
# Max pixel value: 0.24705882
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\ now saving bees_removed_brightened_averaged_40_2
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\bees_removed_brightened_averaged_40_2.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\ now saving average_mask_blurr40_2
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\average_mask_blurr40_2.png
# Min pixel value: 0.007843138
# Max pixel value: 0.24705882
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\ now saving bees_removed_brightened_averaged_blurr40_2
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\bees_removed_brightened_averaged_blurr40_2.png
# Min pixel value: 0.007843138
# Max pixel value: 0.24705882
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\ now saving bees_removed_brightened_averaged_40_1.4
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\bees_removed_brightened_averaged_40_1.4.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\ now saving average_mask_blurr40_1.4
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\average_mask_blurr40_1.4.png
# Min pixel value: 0.007843138
# Max pixel value: 0.24705882
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\ now saving bees_removed_brightened_averaged_blurr40_1.4
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\bees_removed_brightened_averaged_blurr40_1.4.png
# Min pixel value: 0.007843138
# Max pixel value: 0.24705882
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\ now saving bees_removed_brightened_averaged_40_10
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\bees_removed_brightened_averaged_40_10.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\ now saving average_mask_blurr40_10
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\average_mask_blurr40_10.png
# Min pixel value: 0.007843138
# Max pixel value: 0.24313726
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\ now saving bees_removed_brightened_averaged_blurr40_10
# E:\MobotsGroup\cell_classification_KNN\average_40_imgs_skipped5\bees_removed_brightened_averaged_blurr40_10.png

# %%
# # using optical flow to create a filter
def recursive_bee_remover2(first_image, second_image, max_increase = 1.0):
    """ bee remover using the optical flow instead of difference of two consecutive images to compute the mask"""
    flow, mag_of, of_ang = im.compute_dense_optical_flow(first_image, second_image)
    brightened_img, img_mask = brighten_image_with_mask(first_image, mag_of, max_increase)
    return brightened_img, img_mask  

num_images = 40
skipped = 5 # to increase time between images
algorithm_name = "\\optical_flow_{}_imgs_skipped{}".format(num_images, skipped)


####  using the optical flow of the consecutive masks
first_image = cv2.imread(background_filenames[0], cv2.IMREAD_GRAYSCALE)
store_image(first_image, root + algorithm_name, '', "bees_optical_flow_original_{}".format(num_images))

image_list = []
mask_list = []

for filename in background_filenames[1:skipped * num_images][::skipped]:
    second_image = cv2.imread(filename, cv2.IMREAD_GRAYSCALE)
    
    result_img, img_mask = recursive_bee_remover2(first_image, second_image, 1.0) # here used to compute the mask
#     print(filename)
#     print(background_filenames.index(filename)/len(background_filenames) * 100, "%")
    image_list.append(result_img)
    img_mask = img_mask*10 # scale pixel values to obtain a higher value
    mask_list.append(img_mask)
    store_image(img_mask, root + algorithm_name, "\\optical_flow_masks_{}".format(num_images), "_mask_optical_flow_{}".format(background_filenames.index(filename)))

    first_image = second_image
    
    
average_mask = mask_average(mask_list)
if True:
    average_mask = cv2.GaussianBlur(average_mask, (7,7), 0)

store_image(average_mask, root + algorithm_name, '', "mask_optical_flow_{}".format(num_images))

bees_removed_image = remove_moving_objects(image_list)
store_image(bees_removed_image, root + algorithm_name, '', "bees_removed_optical_flow_{}".format(num_images))


for max_increase in [1, 10, 20, 30, 40]:# [0.1, 1, 2, 3, 4]:#
    # added gaussian blur over average mask 
    result, img_maskunused = brighten_image_with_mask(bees_removed_image, average_mask, max_increase)
    store_image(result, root + algorithm_name, '', "bees_removed_brightened_optical_flow_{}_".format(num_images)+str(max_increase))

    average_mask = cv2.GaussianBlur(average_mask, (7,7), 0)
    store_image(average_mask, root + algorithm_name, '', "optical_flow_mask_blurr{}_".format(num_images)+str(max_increase))

    result, img_maskunused = brighten_image_with_mask(bees_removed_image, average_mask, max_increase)
    store_image(result, root + algorithm_name, '', "bees_removed_brightened_optical_flow_blurr{}_".format(num_images)+str(max_increase))

    
# # for filename in background_filenames:
# #     image_list.append(cv2.imread(filename))
    
# resized_image = scale_image(result, 0.5)
# # cv2.imshow('Brightened Img with averaged mask', resized_image)
# # cv2.waitKey(0)
# # cv2.destroyAllWindows()
# Out:
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\ now saving bees_optical_flow_original_40
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\bees_optical_flow_original_40.png
# Min pixel value: 1.6529096e-07
# Max pixel value: 0.1248244
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_1
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_1.png
# Min pixel value: 2.6775103e-07
# Max pixel value: 0.18217447
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_6
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_6.png
# Min pixel value: 8.16676e-08
# Max pixel value: 0.2488744
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_11
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_11.png
# Min pixel value: 1.515337e-07
# Max pixel value: 0.20328932
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_16
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_16.png
# Min pixel value: 1.9540727e-07
# Max pixel value: 0.18975005
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_21
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_21.png
# Min pixel value: 6.957782e-08
# Max pixel value: 0.19530359
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_26
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_26.png
# Min pixel value: 2.4793584e-07
# Max pixel value: 0.21351172
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_31
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_31.png
# Min pixel value: 3.5517743e-07
# Max pixel value: 0.17505391
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_36
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_36.png
# Min pixel value: 4.8621985e-07
# Max pixel value: 0.17780358
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_41
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_41.png
# Min pixel value: 2.3448337e-07
# Max pixel value: 0.21166961
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_46
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_46.png
# Min pixel value: 1.1025726e-06
# Max pixel value: 0.19261427
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_51
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_51.png
# Min pixel value: 3.7029304e-07
# Max pixel value: 0.21403325
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_56
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_56.png
# Min pixel value: 2.3104266e-07
# Max pixel value: 0.16289431
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_61
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_61.png
# Min pixel value: 1.7190524e-07
# Max pixel value: 0.20936401
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_66
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_66.png
# Min pixel value: 3.224301e-07
# Max pixel value: 0.1770296
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_71
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_71.png
# Min pixel value: 1.2840512e-07
# Max pixel value: 0.17058066
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_76
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_76.png
# Min pixel value: 4.426481e-07
# Max pixel value: 0.17578451
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_81
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_81.png
# Min pixel value: 1.6331501e-07
# Max pixel value: 0.17131913
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_86
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_86.png
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\ now saving mask_optical_flow_40
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\mask_optical_flow_40.png
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\ now saving bees_removed_optical_flow_40
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\bees_removed_optical_flow_40.png
# Min pixel value: 0.0
# Max pixel value: 0.4862745
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\ now saving bees_removed_brightened_optical_flow_40_1
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\bees_removed_brightened_optical_flow_40_1.png
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\ now saving optical_flow_mask_blurr40_1
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\optical_flow_mask_blurr40_1.png
# Min pixel value: 0.0
# Max pixel value: 0.48235294
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\ now saving bees_removed_brightened_optical_flow_blurr40_1
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\bees_removed_brightened_optical_flow_blurr40_1.png
# Min pixel value: 0.0
# Max pixel value: 0.48235294
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\ now saving bees_removed_brightened_optical_flow_40_10
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\bees_removed_brightened_optical_flow_40_10.png
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\ now saving optical_flow_mask_blurr40_10
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\optical_flow_mask_blurr40_10.png
# Min pixel value: 0.0
# Max pixel value: 0.47843137
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\ now saving bees_removed_brightened_optical_flow_blurr40_10
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\bees_removed_brightened_optical_flow_blurr40_10.png
# Min pixel value: 0.0
# Max pixel value: 0.47843137
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\ now saving bees_removed_brightened_optical_flow_40_20
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\bees_removed_brightened_optical_flow_40_20.png
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\ now saving optical_flow_mask_blurr40_20
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\optical_flow_mask_blurr40_20.png
# Min pixel value: 0.0
# Max pixel value: 0.47843137
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\ now saving bees_removed_brightened_optical_flow_blurr40_20
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\bees_removed_brightened_optical_flow_blurr40_20.png
# Min pixel value: 0.0
# Max pixel value: 0.47843137
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\ now saving bees_removed_brightened_optical_flow_40_30
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\bees_removed_brightened_optical_flow_40_30.png
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\ now saving optical_flow_mask_blurr40_30
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\optical_flow_mask_blurr40_30.png
# Min pixel value: 0.0
# Max pixel value: 0.4745098
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\ now saving bees_removed_brightened_optical_flow_blurr40_30
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\bees_removed_brightened_optical_flow_blurr40_30.png
# Min pixel value: 0.0
# Max pixel value: 0.4745098
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\ now saving bees_removed_brightened_optical_flow_40_40
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\bees_removed_brightened_optical_flow_40_40.png
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\ now saving optical_flow_mask_blurr40_40
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\optical_flow_mask_blurr40_40.png
# Min pixel value: 0.0
# Max pixel value: 0.47058824
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\ now saving bees_removed_brightened_optical_flow_blurr40_40
# G:\MobotsGroup\cell_classification_KNN\optical_flow_40_imgs_skipped5\bees_removed_brightened_optical_flow_blurr40_40.png

# %%
# # using optical flow to create a filter
def recursive_bee_remover2(first_image, second_image, max_increase = 1.0):
    """ bee remover using the optical flow instead of difference of two consecutive images to compute the mask"""
    flow, mag_of, of_ang = im.compute_dense_optical_flow(first_image, second_image)
    brightened_img, img_mask = brighten_image_with_mask_multiplication(first_image, mag_of, max_increase)
    return brightened_img, img_mask


def brighten_image_with_mask_multiplication(main_img, mask_img, max_increase=1.0):
    """
    Brighten the main image using the mask image, proportional to the mask's pixel values.
    
    Parameters:
    - main_img: Main image (cv2 image object, should be uint8)
    - mask_img: Mask image (cv2 image object, should be uint8, same size as main_img)
    - max_increase: Maximum scaling factor to increase brightness based on mask

    Returns:
    - brightened_img: Image with brightness increased based on mask
    """
    if main_img.shape != mask_img.shape:
        raise ValueError("Main image and mask image must have the same dimensions")

    main_img = main_img.astype(np.float32)

    # Normalize mask to range [0, 1] by dividing by 255 (if the mask is uint8)
    mask_img = mask_img.astype(np.float32) / 255.0
    
    if True:
        average_mask = cv2.GaussianBlur(mask_img, (21,21), 0)
    
    # Increase brightness proportional to the mask values
    brightened_img = cv2.multiply(main_img, mask_img, scale=1/255.0) * max_increase

    brightened_img = np.clip(brightened_img, 0, 255).astype(np.uint8)
    
    print("Min pixel value:", mask_img.min())
    print("Max pixel value:", mask_img.max())
    mask_img = (mask_img.astype(np.float32) * 255.0).astype(np.uint8)
    
    return brightened_img, mask_img

    

num_images = 40
skipped = 5 # to increase time between images
algorithm_name = "\\optical_flow_multiplication_{}_imgs_skipped{}".format(num_images, skipped)


####  using the optical flow of the consecutive masks
first_image = cv2.imread(background_filenames[0], cv2.IMREAD_GRAYSCALE)
store_image(first_image, root + algorithm_name, '', "bees_optical_flow_original_{}".format(num_images))

image_list = []
mask_list = []

for filename in background_filenames[1:skipped * num_images][::skipped]:
    second_image = cv2.imread(filename, cv2.IMREAD_GRAYSCALE)
    
    result_img, img_mask = recursive_bee_remover2(first_image, second_image, 1.0) # here used to compute the mask
#     print(filename)
#     print(background_filenames.index(filename)/len(background_filenames) * 100, "%")
    image_list.append(result_img)
    img_mask = img_mask*10 # scale pixel values to obtain a higher value
    mask_list.append(img_mask)
    store_image(img_mask, root + algorithm_name, "\\optical_flow_masks_{}".format(num_images), "_mask_optical_flow_{}".format(background_filenames.index(filename)))

    first_image = second_image
    
    
average_mask = mask_average(mask_list)


store_image(average_mask, root + algorithm_name, '', "mask_optical_flow_{}".format(num_images))

bees_removed_image = remove_moving_objects(image_list)
store_image(bees_removed_image, root + algorithm_name, '', "bees_removed_optical_flow_{}".format(num_images))


for max_increase in [1, 10, 20, 30, 40]:# [0.1, 1, 2, 3, 4]:#
    # added gaussian blur over average mask 
    result, img_maskunused = brighten_image_with_mask_multiplication(bees_removed_image, average_mask, max_increase)
    store_image(result, root + algorithm_name, '', "bees_removed_brightened_optical_flow_{}_".format(num_images)+str(max_increase))

    average_mask = cv2.GaussianBlur(average_mask, (21,21), 0)
    store_image(average_mask, root + algorithm_name, '', "optical_flow_mask_blurr{}_".format(num_images)+str(max_increase))

    result, img_maskunused = brighten_image_with_mask_multiplication(bees_removed_image, average_mask, max_increase)
    store_image(result, root + algorithm_name, '', "bees_removed_brightened_optical_flow_blurr{}_".format(num_images)+str(max_increase))

    
# # for filename in background_filenames:
# #     image_list.append(cv2.imread(filename))
    
# resized_image = scale_image(result, 0.5)
# # cv2.imshow('Brightened Img with averaged mask', resized_image)
# # cv2.waitKey(0)
# # cv2.destroyAllWindows()
# Out:
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\ now saving bees_optical_flow_original_40
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\bees_optical_flow_original_40.png
# Min pixel value: 1.6529096e-07
# Max pixel value: 0.1248244
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_1
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_1.png
# Min pixel value: 2.6775103e-07
# Max pixel value: 0.18217447
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_6
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_6.png
# Min pixel value: 8.16676e-08
# Max pixel value: 0.2488744
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_11
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_11.png
# Min pixel value: 1.515337e-07
# Max pixel value: 0.20328932
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_16
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_16.png
# Min pixel value: 1.9540727e-07
# Max pixel value: 0.18975005
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_21
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_21.png
# Min pixel value: 6.957782e-08
# Max pixel value: 0.19530359
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_26
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_26.png
# Min pixel value: 2.4793584e-07
# Max pixel value: 0.21351172
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_31
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_31.png
# Min pixel value: 3.5517743e-07
# Max pixel value: 0.17505391
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_36
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_36.png
# Min pixel value: 4.8621985e-07
# Max pixel value: 0.17780358
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_41
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_41.png
# Min pixel value: 2.3448337e-07
# Max pixel value: 0.21166961
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_46
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_46.png
# Min pixel value: 1.1025726e-06
# Max pixel value: 0.19261427
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_51
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_51.png
# Min pixel value: 3.7029304e-07
# Max pixel value: 0.21403325
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_56
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_56.png
# Min pixel value: 2.3104266e-07
# Max pixel value: 0.16289431
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_61
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_61.png
# Min pixel value: 1.7190524e-07
# Max pixel value: 0.20936401
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_66
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_66.png
# Min pixel value: 3.224301e-07
# Max pixel value: 0.1770296
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_71
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_71.png
# Min pixel value: 1.2840512e-07
# Max pixel value: 0.17058066
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_76
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_76.png
# Min pixel value: 4.426481e-07
# Max pixel value: 0.17578451
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_81
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_81.png
# Min pixel value: 1.6331501e-07
# Max pixel value: 0.17131913
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\\optical_flow_masks_40 now saving _mask_optical_flow_86
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\optical_flow_masks_40\\optical_flow_masks_40_mask_optical_flow_86.png
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\ now saving mask_optical_flow_40
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\mask_optical_flow_40.png
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\ now saving bees_removed_optical_flow_40
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\bees_removed_optical_flow_40.png
# Min pixel value: 0.0
# Max pixel value: 0.53333336
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\ now saving bees_removed_brightened_optical_flow_40_1
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\bees_removed_brightened_optical_flow_40_1.png
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\ now saving optical_flow_mask_blurr40_1
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\optical_flow_mask_blurr40_1.png
# Min pixel value: 0.0
# Max pixel value: 0.47058824
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\ now saving bees_removed_brightened_optical_flow_blurr40_1
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\bees_removed_brightened_optical_flow_blurr40_1.png
# Min pixel value: 0.0
# Max pixel value: 0.47058824
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\ now saving bees_removed_brightened_optical_flow_40_10
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\bees_removed_brightened_optical_flow_40_10.png
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\ now saving optical_flow_mask_blurr40_10
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\optical_flow_mask_blurr40_10.png
# Min pixel value: 0.0
# Max pixel value: 0.45490196
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\ now saving bees_removed_brightened_optical_flow_blurr40_10
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\bees_removed_brightened_optical_flow_blurr40_10.png
# Min pixel value: 0.0
# Max pixel value: 0.45490196
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\ now saving bees_removed_brightened_optical_flow_40_20
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\bees_removed_brightened_optical_flow_40_20.png
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\ now saving optical_flow_mask_blurr40_20
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\optical_flow_mask_blurr40_20.png
# Min pixel value: 0.0
# Max pixel value: 0.4392157
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\ now saving bees_removed_brightened_optical_flow_blurr40_20
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\bees_removed_brightened_optical_flow_blurr40_20.png
# Min pixel value: 0.0
# Max pixel value: 0.4392157
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\ now saving bees_removed_brightened_optical_flow_40_30
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\bees_removed_brightened_optical_flow_40_30.png
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\ now saving optical_flow_mask_blurr40_30
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\optical_flow_mask_blurr40_30.png
# Min pixel value: 0.0
# Max pixel value: 0.43137255
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\ now saving bees_removed_brightened_optical_flow_blurr40_30
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\bees_removed_brightened_optical_flow_blurr40_30.png
# Min pixel value: 0.0
# Max pixel value: 0.43137255
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\ now saving bees_removed_brightened_optical_flow_40_40
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\bees_removed_brightened_optical_flow_40_40.png
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\ now saving optical_flow_mask_blurr40_40
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\optical_flow_mask_blurr40_40.png
# Min pixel value: 0.0
# Max pixel value: 0.42352942
# Folder already exists at: G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\ now saving bees_removed_brightened_optical_flow_blurr40_40
# G:\MobotsGroup\cell_classification_KNN\optical_flow_multiplication_40_imgs_skipped5\bees_removed_brightened_optical_flow_blurr40_40.png

# %% [markdown]
# # Observations
#
# multiplication is overall noisier than addition, as it seems.
# when using multiplication, without gaussian blurr, a very noisy image is obtained with kernel size 7x7
# first approaches with knn and mog2 averaging seem to remove the bees more reliably, yet, the dark shadows then created will have to be removed by detecting the darkest regions of the image and increase brightness in those regions

# %%
# Out:
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\\opticalFlow now saving of_mag
# E:\MobotsGroup\cell_classification_KNN\opticalFlow\\opticalFlowof_mag.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\\opticalFlow now saving firstimag
# E:\MobotsGroup\cell_classification_KNN\opticalFlow\\opticalFlowfirstimag.png
# Folder already exists at: E:\MobotsGroup\cell_classification_KNN\\opticalFlow now saving secondimag
# E:\MobotsGroup\cell_classification_KNN\opticalFlow\\opticalFlowsecondimag.png

# %% [markdown]
# # Implementation of approach of DeepBee project
# All code hereafter is taken from or inspired by the DeepBee project. Applying it to the results did not seem to lead to satisfying results and the source code for changing the model itself could not be found. -> Might be worth creating a new model based on the image data of images gathered at Bassenges. The models provided by DeepBee did not provide satisfying results, not even after retraining with our data.

# %%
# # Get a list of image paths
# # image_paths = sorted(glob(os.path.join(image_folder, '*.jpg')))  # Change the extension if necessary
# # image_paths

# # Initialize the background subtractor
# backSub = cv2.createBackgroundSubtractorMOG2(history=100, varThreshold=50, detectShadows=False)

# for i, image_path in enumerate(image_paths):
#     # Read the image
#     frame = cv2.imread(image_path)
    
#     # Apply the background subtractor
#     fg_mask = backSub.apply(frame)
    
#     # Optional: Improve mask using morphological operations
#     kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
#     fg_mask = cv2.morphologyEx(fg_mask, cv2.MORPH_CLOSE, kernel)
#     fg_mask = cv2.morphologyEx(fg_mask, cv2.MORPH_OPEN, kernel)
    
#     # Invert the mask to get the background (cells) only
#     bg_mask = cv2.bitwise_not(fg_mask)
    
#     # Use the mask to extract the background
#     bg = cv2.bitwise_and(frame, frame, mask=bg_mask)
    
#     # Save the result
#     output_path = os.path.join(output_folder, f'processed_{i:04d}.jpg')
#     cv2.imwrite(output_path, bg)

#     # Display the result for verification
#     cv2.imshow('Background', bg)
#     cv2.waitKey(30)  # Display each image for 30 ms

# cv2.destroyAllWindows()

# %%
# # Load all images and store them in a list
# images = []
# for image_path in image_paths:
#     img = cv2.imread(image_path)
#     if img is not None:
#         images.append(img)

# # Convert the list of images to a NumPy array
# images_np = np.array(images, dtype=np.float32)

# # Compute the median along the time axis
# median_background = np.median(images_np, axis=0).astype(np.uint8)

# # Initialize the background subtractor
# backSub = cv2.createBackgroundSubtractorMOG2(history=100, varThreshold=50, detectShadows=False)


# # Process each image by subtracting the median background
# for i, image_path in enumerate(image_paths):
#     # Read the current image
#     frame = cv2.imread(image_path)
    
#     # Subtract the median background
#     fg_mask = cv2.absdiff(frame, median_background)
    
#     # Convert to grayscale
#     fg_mask_gray = cv2.cvtColor(fg_mask, cv2.COLOR_BGR2GRAY)
    
#     # Apply a binary threshold to get a binary mask
#     _, fg_mask_bin = cv2.threshold(fg_mask_gray, 30, 255, cv2.THRESH_BINARY)
    
#     # Optional: Improve mask using morphological operations
#     kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
#     fg_mask_bin = cv2.morphologyEx(fg_mask_bin, cv2.MORPH_CLOSE, kernel)
#     fg_mask_bin = cv2.morphologyEx(fg_mask_bin, cv2.MORPH_OPEN, kernel)
    
#     # Invert the mask to get the background (cells) only
#     bg_mask = cv2.bitwise_not(fg_mask_bin)
    
#     # Use the mask to extract the background
#     bg = cv2.bitwise_and(frame, frame, mask=bg_mask)
    
#     # Save the result
#     output_path = os.path.join(output_folder, f'processed_{i:04d}.jpg')
#     cv2.imwrite(output_path, bg)

#     # Display the result for verification
#     cv2.imshow('Background', bg)
#     cv2.waitKey(30)  # Display each image for 30 ms

# cv2.destroyAllWindows()

# %% [markdown]
# # Enhance image

# %%
def increase_contrast(image):
    # Convert to YUV color space
    yuv = cv2.cvtColor(image, cv2.COLOR_BGR2YUV)
    
    # Apply CLAHE to the Y channel (luminance)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    yuv[:, :, 0] = clahe.apply(yuv[:, :, 0])
    
    # Convert back to BGR color space
    enhanced_image = cv2.cvtColor(yuv, cv2.COLOR_YUV2BGR)
    
    return enhanced_image

def sharpen_image(image):
    # Create a sharpening kernel
    kernel = np.array([[0, -1, 0],
                       [-1, 4,-1],
                       [0, -1, 0]])
    
    # Apply the sharpening kernel to the image
    sharpened_image = cv2.filter2D(image, -1, kernel)
    
    return sharpened_image

def remove_distortion(image):    # TODO add if needed
    undistorted_image = image
    return undistorted_image
    


# Example usage
# Assuming result_image is the output from your background subtraction process
undistorted_image = remove_distortion(result_image)
contrast_image = increase_contrast(undistorted_image)
sharpened_image = sharpen_image(contrast_image)


# Save or display the result image


preprocessed_filename = output_folder + '\\output_image_contrast_sharpened.jpg'.format(first_index, downsampling)
cv2.imwrite(preprocessed_filename, result_image)
print("processed image successfully written to: ")
print(preprocessed_filename)
# cv2.imshow('Sharpened Image', sharpened_image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %% [markdown]
# # Image segmentation

# %%
processed_filename = r"E:\MobotsGroup\output\2024-08-12_09-21-01_imgs216_numdays3_step20\output_image_contrast_sharpened.jpg"
processed_img = cv2.imread(processed_filename)

print(processed_img.shape)
plt.imshow(processed_img)
plt.show()

# %%
# # Image loading and resizing
# original_shape = (4608, 2592)  # Desired image shape
# img = processed_img


# def convert_bgr_to_rgb(img):
#     return cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# # Image loading

# print(f"Original Shape: {img.shape[:2]}")

# # Resize to the desired shape if not already
# if img.shape[:2] != original_shape:
#     img = cv2.resize(img, (original_shape[0], original_shape[1]))  # (width, height)
# print(f"Resized Shape: {img.shape[:2]}")

# # Add mirrored border
# top_border = bottom_border = 184  # Adjust these based on desired overlap and slice size
# left_border = right_border = 148
# reflect = cv2.copyMakeBorder(img, top_border, bottom_border, left_border, right_border, cv2.BORDER_REFLECT)

# plt.imshow(convert_bgr_to_rgb(reflect))
# plt.title('Image with Mirrored Border')
# plt.axis('off')  # Hide axes
# plt.show()

# # Define overlap and step size
# overlap = 128
# slice_size = 512
# step_size = slice_size - overlap

# # Calculate positions for slicing
# pos_x = np.arange(0, original_shape[1] + 2 * left_border - slice_size + 1, step_size)
# pos_y = np.arange(0, original_shape[0] + 2 * top_border - slice_size + 1, step_size)

# # Generate slices
# slices = [np.s_[y[0]:y[1], x[0]:x[1]] for x in zip(pos_x, pos_x + slice_size) for y in zip(pos_y, pos_y + slice_size)]
# print(f"Examples of slices: {slices[:2]}")

# # Extract all the tiles and resize them to 128x128px (model input shape)
# IMG_WIDTH = 128
# IMG_HEIGHT = 128
# IMG_CHANNELS = 3

# X = np.zeros((len(slices), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)

# for j, sl in enumerate(slices):
#     print(j, sl)
#     if reflect[sl].size == 0:
#         print(f"Skipping empty slice at index {j}")
#         continue
#     else:# Corrected dimensions for cv2.resize: (width, height)
#         X[j] = cv2.resize(reflect[sl], (IMG_WIDTH, IMG_HEIGHT), interpolation=cv2.INTER_AREA)

# # Plotting the tiles extracted
# def plot_tiles(X, func) -> None:
#     num_tiles_y = len(pos_y)
#     num_tiles_x = len(pos_x)

#     f, axarr = plt.subplots(num_tiles_y, num_tiles_x, figsize=(10, 10))
#     f.subplots_adjust(hspace=-0.8, wspace=.1)
#     img_index = 0

#     for i in range(num_tiles_y):
#         for j in range(num_tiles_x):
#             if img_index < len(X):  # Check to avoid index out of bounds
#                 axarr[i, j].imshow(func(X[img_index]), vmin=0, vmax=255)
#             axarr[i, j].axis('off')
#             img_index += 1

#     plt.show()

# plot_tiles(X, convert_bgr_to_rgb)

# %%
def convert_bgr_to_rgb(img):
    return cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
original_shape = processed_img.shape[:2]
print(f"Original Shape: {original_shape}", "ratio 16:9 ?")



if original_shape != (2592, 4608):
    resized_img = cv2.resize(processed_img, (2592, 4608))

    resized_shape = resized_img.shape[:2]
    print(f"Resized image, shape now: {resized_shape}")
    plt.imshow(resized_img)
    plt.show()
else:
    resized_img = processed_img

# %%
# Adds a frame consisting of the mirrored border of the image
reflect = cv2.copyMakeBorder(resized_img, 184, 184, 148, 148, cv2.BORDER_REFLECT)
reflect.shape

# %%
plt.imshow(convert_bgr_to_rgb(reflect))
plt.show()

# %%
# overlap = 64
# slice_size = 512
# step_size = slice_size - overlap  
# reflect_x = 2960
# reflect_y = 4904

# pos_x = np.arange(0, reflect_x - slice_size + 1, step_size)
# pos_y = np.arange(0, reflect_y - slice_size + 1, step_size)

# slices = [np.s_[ x[0]:x[1], y[0]:y[1]] for x in zip(pos_x, pos_x + slice_size) for y in zip(pos_y, pos_y + slice_size)  ]
# print(f"Exemples of slices: {slices[:2]}")

# %%
# IMG_WIDTH = 128
# IMG_HEIGHT = 128
# IMG_CHANNELS = 3

# X = np.zeros((len(slices), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)

# good_indices = 0    
# for j, sl in enumerate(slices): 
    
#     print(j, sl, good_indices)
#     slice_img = reflect[sl]
#     print(f"Processing slice {j}, Slice shape: {slice_img.shape}")

# #     Check if the slice is empty or has unexpected dimensions
#     if slice_img.size == 0:
#         print(f"--- ----  Skipping empty slice at index {j}")
#         continue
#     elif slice_img.shape[0] != 512 or slice_img.shape[1] != 512:
#         print(f"Skipping invalid slice with shape {slice_img.shape} at index {j}")
#         continue
#     else:
#         X[good_indices] = cv2.resize(reflect[sl],(IMG_HEIGHT, IMG_WIDTH), interpolation=cv2.INTER_AREA)
#         good_indices +=1

# %%
# for i, slice_img in enumerate(X):
#     if slice_img.sum() == 0:  # This checks if the slice is completely black
#         print(f"Slice {i} is empty or black")
# print(len(X))

# %%
def cut_tiles(image):
    overlap = 64
    slice_size = 512
    step_size = slice_size - overlap  
    reflect_x = 2960
    reflect_y = 4904

    pos_x = np.arange(0, reflect_x - slice_size + 1, step_size)
    pos_y = np.arange(0, reflect_y - slice_size + 1, step_size)

    slices = [np.s_[ x[0]:x[1], y[0]:y[1]] for x in zip(pos_x, pos_x + slice_size) for y in zip(pos_y, pos_y + slice_size)  ]
    print(f"Exemples of slices: {slices[:2]}")
    
    IMG_WIDTH = 128
    IMG_HEIGHT = 128
    IMG_CHANNELS = 3

    X = np.zeros((len(slices), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)

    good_indices = 0    
    for j, sl in enumerate(slices): 

        slice_img = image[sl]
#         print(f"Processing slice {j}, Slice shape: {slice_img.shape}")

    #     Check if the slice is empty or has unexpected dimensions
        if slice_img.size == 0:
            print(f"--- ----  Skipping empty slice at index {j}")
            continue
        elif slice_img.shape[0] != 512 or slice_img.shape[1] != 512:
            print(f"Skipping invalid slice with shape {slice_img.shape} at index {j}")
            continue
        else:
            X[good_indices] = cv2.resize(image[sl],(IMG_HEIGHT, IMG_WIDTH), interpolation=cv2.INTER_AREA)
            good_indices +=1
    return X
    
X = cut_tiles(reflect)

# %%
# Plotting the tiles extracted
def plot_tiles(X, func) -> None:
    f, axarr = plt.subplots(6, 11,  figsize=(10,10))
    f.subplots_adjust(hspace=-0.8, wspace=.1)
    img_index = 0
    

    for j in range(6):
        for i in range(10):
            while X[img_index].sum() == 0:  # This checks if the slice is completely black
                print(f"Slice {img_index} is empty or black")
                img_index += 1
            axarr[j,i].imshow(func(X[img_index]), vmin=0, vmax=255)
            axarr[j,i].axis('off')
            img_index += 1
            
plot_tiles(X, convert_bgr_to_rgb)

# %%
# print(len(np.arange(0, 4608 - 512 + 1, 384)),   len(np.arange(0, 2592 - 512 + 1, 384)))

# %%
model_path = root + r"\Models\segmentation.h5"
model_path = r"E:\MobotsGroup\Models\segmentation.h5"
print(model_path)
model = load_model(model_path)

# %%
print(tf.__version__)

# %% [markdown]
# # Detect hexagonal structures on each slice

# %%
def detect_hexagons(image, draw_hexagons=True):
    # Load the image
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Apply Gaussian Blur to reduce noise
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)
    
    # Use Canny Edge Detector
    edges = cv2.Canny(blurred, 50, 150)
    
    # Detect contours in the image
    contours, _ = cv2.findContours(edges, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    
    hexagon_centers = []
    
    for contour in contours:
        # Approximate the contour to a polygon
        epsilon = 0.02 * cv2.arcLength(contour, True)
        approx = cv2.approxPolyDP(contour, epsilon, True)
        
        # Check if the polygon has 6 sides (i.e., a hexagon)
        if len(approx) == 6:
            # Compute the center of the hexagon
            M = cv2.moments(approx)
            if M["m00"] != 0:
                center_x = int(M["m10"] / M["m00"])
                center_y = int(M["m01"] / M["m00"])
            else:
                continue
            
            hexagon_centers.append((center_x, center_y))
            
            if draw_hexagons:
                # Draw the hexagon and its center on the image
                cv2.drawContours(image, [approx], 0, (0, 255, 0), 2)
                cv2.circle(image, (center_x, center_y), 5, (0, 0, 255), -1)
    
    # Display the result if draw_hexagons is True
    if draw_hexagons:
        cv2.imshow('Hexagons Detected', image)
        cv2.waitKey(0)
        cv2.destroyAllWindows()

    return hexagon_centers

# %%
detect_hexagons(X[12])
